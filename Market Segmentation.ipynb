# %% [markdown]
# # Unsupervised Machine Learning Project

# %% [markdown]
# # Market segmentation

# %% [markdown]
# # step 1: Problem statement:
# Develope a customer segementation to give recommendation like saving plans, loans,wealth management,etc on target customers groups

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # step 2 : Data Gathering

# %%
df=pd.read_csv('customer_data.csv')
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %% [markdown]
# # step 3: EDA

# %%
df.shape # how big data is
# Out:
# (8950, 18)

# %%
df.info() # rough idea about null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.describe() # to get the statistical information about data
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
 (df.isnull().sum()/len(df))*100
# Out:
# CUST_ID                             0.000000
# BALANCE                             0.000000
# BALANCE_FREQUENCY                   0.000000
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.000000
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.000000
# CASH_ADVANCE_TRX                    0.000000
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.011173
# PAYMENTS                            0.000000
# MINIMUM_PAYMENTS                    3.497207
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              0.000000
# dtype: float64

# %% [markdown]
# ### 3.49 % missing values (<5%)so i can remove or impute that values

# %%
# filling missing values with mean values

# %%
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
df_columns=[i.lower() for i in df.columns]

# %%
df_columns
# Out:
# ['cust_id',
#  'balance',
#  'balance_frequency',
#  'purchases',
#  'oneoff_purchases',
#  'installments_purchases',
#  'cash_advance',
#  'purchases_frequency',
#  'oneoff_purchases_frequency',
#  'purchases_installments_frequency',
#  'cash_advance_frequency',
#  'cash_advance_trx',
#  'purchases_trx',
#  'credit_limit',
#  'payments',
#  'minimum_payments',
#  'prc_full_payment',
#  'tenure']

# %%
col_names=dict(zip(df.columns,df_columns)) # to create dict using two list

# %%
# now change the column_names becoz i dont like col_names in capital so convert it into lower and replace

# %%
df.columns=df_columns  # this is how i can rename all column names of my df

# %%
df
# Out:
#      cust_id      balance  balance_frequency  purchases  oneoff_purchases  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       installments_purchases  cash_advance  purchases_frequency  \
# ...

# %% [markdown]
# ### creating backup

# %%
backup=df.copy()

# %%
# Out:
#      cust_id      balance  balance_frequency  purchases  oneoff_purchases  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       installments_purchases  cash_advance  purchases_frequency  \
# ...

# %% [markdown]
# ### 3.1. Handline missing values

# %%
df.isna().sum()
# Out:
# cust_id                               0
# balance                               0
# balance_frequency                     0
# purchases                             0
# oneoff_purchases                      0
# installments_purchases                0
# cash_advance                          0
# purchases_frequency                   0
# oneoff_purchases_frequency            0
# purchases_installments_frequency      0
# cash_advance_frequency                0
# cash_advance_trx                      0
# purchases_trx                         0
# credit_limit                          1
# payments                              0
# minimum_payments                    313
# prc_full_payment                      0
# tenure                                0
# dtype: int64

# %%
df['minimum_payments']
# Out:
# 0        139.509787
# 1       1072.340217
# 2        627.284787
# 3               NaN
# 4        244.791237
#            ...
# 8945      48.886365
# 8946            NaN
# 8947      82.418369
# 8948      55.755628
# 8949      88.288956
# Name: minimum_payments, Length: 8950, dtype: float64

# %%
sns.histplot(df['minimum_payments'])

# %%
sns.distplot(df['minimum_payments'])
# Out:
# C:\Users\Dayton\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['minimum_payments'].mean()
# Out:
# 864.2065423050814

# %%
df['minimum_payments'].median()
# Out:
# 312.343947

# %%
df['minimum_payments'].min()
# Out:
# 0.019163

# %%
df['minimum_payments'].max()
# Out:
# 76406.20752000001

# %%
df['minimum_payments']=df['minimum_payments'].fillna(df['minimum_payments'].mean())
df['credit_limit']=df['credit_limit'].fillna(df['credit_limit'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   cust_id                           8950 non-null   object
#  1   balance                           8950 non-null   float64
#  2   balance_frequency                 8950 non-null   float64
#  3   purchases                         8950 non-null   float64
#  4   oneoff_purchases                  8950 non-null   float64
#  5   installments_purchases            8950 non-null   float64
#  6   cash_advance                      8950 non-null   float64
#  7   purchases_frequency               8950 non-null   float64
#  8   oneoff_purchases_frequency        8950 non-null   float64
#  9   purchases_installments_frequency  8950 non-null   float64
#  10  cash_advance_frequency            8950 non-null   float64
# ...

# %% [markdown]
# ### checking for duplicate rows in dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### drop cust_id column because it is of no use

# %%
df.drop(columns=['cust_id'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['balance', 'balance_frequency', 'purchases', 'oneoff_purchases',
#        'installments_purchases', 'cash_advance', 'purchases_frequency',
#        'oneoff_purchases_frequency', 'purchases_installments_frequency',
#        'cash_advance_frequency', 'cash_advance_trx', 'purchases_trx',
#        'credit_limit', 'payments', 'minimum_payments', 'prc_full_payment',
#        'tenure'],
#       dtype='object')

# %%
len(df.columns)  # previously 18
# Out:
# 17

# %% [markdown]
# ### ploting my graph to see the distribution of each feature
#
# ### to see wheather they follow normal distribution or not

# %%
plt.figure(figsize=(30,45))
for i,col in enumerate(df.columns):
    if df[col].dtype !='object':
        ax=plt.subplot(9,2,i+1)
        sns.kdeplot(df[col],ax=ax)
        plt.xlabel(col)
plt.show()

# %%
plt.figure(figsize=(10,60))
for i in range(1,17):
    plt.subplot(17,1,i+1)
    sns.distplot(df[df.columns[i]],kde_kws={'color':'b','bw':0.1,'lw':3,'label':'KDE'},hist_kws={'color':'g'})
    plt.title(df.columns[i])
plt.tight_layout()
# Out:
# C:\Users\Dayton\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dayton\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dayton\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# # scaling the dataframe

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaled_arr=scaler.fit_transform(df)

# %%
scaled_arr
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.31096755,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.08931021,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.10166318,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.33546549,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.34690648,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.33294642,
#         -0.52555097, -4.12276757]])

# %%
scaled_df=pd.DataFrame(scaled_arr,columns=df.columns)

# %%
scaled_df
# Out:
#        balance  balance_frequency  purchases  oneoff_purchases  \
# 0    -0.731989          -0.249434  -0.424900         -0.356934
# 1     0.786961           0.134325  -0.469552         -0.356934
# 2     0.447135           0.518084  -0.107668          0.108889
# 3     0.049099          -1.016953   0.232058          0.546189
# 4    -0.358775           0.518084  -0.462063         -0.347294
# ...        ...                ...        ...               ...
# 8945 -0.737950           0.518084  -0.333293         -0.356934
# 8946 -0.742423           0.518084  -0.329136         -0.356934
# 8947 -0.740398          -0.185477  -0.401965         -0.356934
# 8948 -0.745174          -0.185477  -0.469552         -0.356934
# 8949 -0.572575          -0.889033   0.042146          0.301732
#
#       installments_purchases  cash_advance  purchases_frequency  \
# 0                  -0.349079     -0.466786            -0.806490
# 1                  -0.454576      2.605605            -1.221758
# ...

# %% [markdown]
# ## Dimensionality Reduction

# %% [raw]
# converting the dataframe into 2D dataframe for visualization

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)
principal_components=pca.fit_transform(scaled_arr)
pca_df=pd.DataFrame(data=principal_components,columns=['PCA1','PCA2'])
pca_df
# Out:
#           PCA1      PCA2
# 0    -1.682221 -1.076450
# 1    -1.138295  2.506484
# 2     0.969682 -0.383529
# 3    -0.873628  0.043168
# 4    -1.599434 -0.688582
# ...        ...       ...
# 8945 -0.359630 -2.016149
# 8946 -0.564370 -1.639125
# 8947 -0.926204 -1.810788
# 8948 -2.336551 -0.657966
# 8949 -0.556421 -0.400467
#
# [8950 rows x 2 columns]

# %% [markdown]
# ## hyperparameter tuning

# %% [markdown]
# ### finding 'k' value by Elbow Method

# %%
from sklearn.cluster import KMeans,AgglomerativeClustering,DBSCAN,SpectralClustering

# %%
inertia=[]
range_val=range(1,15)
for i in range_val:
    kmeans=KMeans(n_clusters=i)
    kmeans.fit_predict(scaled_df)
    inertia.append(kmeans.inertia_)
plt.plot(range_val,inertia,'bx-')
plt.xlabel('values of k')
plt.ylabel('Inertia')
plt.title('The Elbow Method using Inertia')
plt.show()

# %% [markdown]
# # Model Building using KMeans

# %%
kmeans_model=KMeans(4)
kmeans_model.fit_predict(scaled_arr)
pca_df_kmeans=pd.concat([pca_df,pd.DataFrame({'cluster':kmeans_model.labels_})],axis=1)

# %%
pca_df_kmeans
# Out:
#           PCA1      PCA2  cluster
# 0    -1.682221 -1.076450        2
# 1    -1.138295  2.506484        0
# 2     0.969682 -0.383529        1
# 3    -0.873628  0.043168        2
# 4    -1.599434 -0.688582        2
# ...        ...       ...      ...
# 8945 -0.359630 -2.016149        1
# 8946 -0.564370 -1.639125        1
# 8947 -0.926204 -1.810788        1
# 8948 -2.336551 -0.657966        2
# 8949 -0.556421 -0.400467        2
#
# [8950 rows x 3 columns]

# %% [markdown]
# # visualizing the clustered dataframe

# %%
plt.figure(figsize=(8,8))
ax=sns.scatterplot(x='PCA1',y='PCA2',hue='cluster',data=pca_df_kmeans,palette=['red','green','yellow','orange'])
plt.title('Clustering using KMeans Algorithm')
plt.show()

# %% [markdown]
# ### find all cluster centers

# %%
cluster_centers=pd.DataFrame(data=kmeans_model.cluster_centers_,columns=[df.columns])

# %%
kmeans_model.cluster_centers_
# Out:
# array([[ 1.46049699e+00,  3.84530104e-01, -2.34274942e-01,
#         -1.63591237e-01, -2.53480477e-01,  1.69071814e+00,
#         -5.04169541e-01, -2.12160303e-01, -4.49771293e-01,
#          1.74721151e+00,  1.61843813e+00, -2.83198829e-01,
#          8.40712772e-01,  6.05389118e-01,  4.91471710e-01,
#         -4.06167977e-01, -9.79116180e-02],
#        [-3.21755013e-01,  2.42492148e-01,  1.09083463e-01,
#          9.39008574e-04,  2.55973933e-01, -3.66732314e-01,
#          9.83944240e-01,  3.17282537e-01,  8.74358420e-01,
#         -4.63030429e-01, -3.60443140e-01,  2.97022123e-01,
#         -7.70764637e-02, -1.38802081e-01, -9.18159333e-02,
#          3.95230306e-01,  5.76539298e-02],
#        [-2.64918620e-01, -3.68275514e-01, -3.43164756e-01,
#         -2.30516554e-01, -3.87708390e-01, -1.82017059e-01,
#         -7.97620412e-01, -3.89514595e-01, -7.14029743e-01,
#         -1.00677154e-01, -1.64031912e-01, -4.74842974e-01,
# ...

# %%
cluster_centers
# Out:
#     balance balance_frequency purchases oneoff_purchases  \
# 0  1.460497          0.384530 -0.234275        -0.163591
# 1 -0.321755          0.242492  0.109083         0.000939
# 2 -0.264919         -0.368276 -0.343165        -0.230517
# 3  0.954485          0.462694  3.125845         2.713251
#
#   installments_purchases cash_advance purchases_frequency  \
# 0              -0.253480     1.690718           -0.504170
# 1               0.255974    -0.366732            0.983944
# 2              -0.387708    -0.182017           -0.797620
# 3               2.406470    -0.155091            1.136338
#
#   oneoff_purchases_frequency purchases_installments_frequency  \
# 0                  -0.212160                        -0.449771
# 1                   0.317283                         0.874358
# 2                  -0.389515                        -0.714030
# 3                   1.798653                         1.065918
#
# ...

# %% [markdown]
# ## inverse transforming  the data

# %%
cluster_centers=scaler.inverse_transform(cluster_centers)
cluster_centers=pd.DataFrame(data=cluster_centers,columns=[df.columns])
cluster_centers
# Out:
#        balance balance_frequency    purchases oneoff_purchases  \
# 0  4604.376032          0.968362   502.672809       320.909423
# 1   894.768927          0.934715  1236.263333       593.995933
# 2  1013.069082          0.790030   270.028042       209.827105
# 3  3551.153761          0.986879  7681.620098      5095.878826
#
#   installments_purchases cash_advance purchases_frequency  \
# 0             181.848395  4524.386039            0.288003
# 1             642.541696   209.816318            0.885255
# 2              60.467758   597.172838            0.170227
# 3            2587.208264   653.638891            0.946418
#
#   oneoff_purchases_frequency purchases_installments_frequency  \
# 0                   0.139166                         0.185687
# 1                   0.297109                         0.711930
# 2                   0.086258                         0.080664
# 3                   0.739031                         0.788060
#
# ...

# %% [markdown]
# ## creating a target column 'Cluster' for storing the cluster segement

# %%
cluster_df=pd.concat([df,pd.DataFrame({'Cluster':kmeans_model.labels_})],axis=1)
cluster_df
# Out:
#           balance  balance_frequency  purchases  oneoff_purchases  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       installments_purchases  cash_advance  purchases_frequency  \
# 0                      95.40      0.000000             0.166667
# ...

# %% [markdown]
# ## create each df for each cluster

# %%
cluster_df['Cluster'].value_counts()
# Out:
# 2    3978
# 1    3366
# 0    1197
# 3     409
# Name: Cluster, dtype: int64

# %%
cluster_1_df=cluster_df[cluster_df['Cluster']==0]
cluster_2_df=cluster_df[cluster_df['Cluster']==1]
cluster_3_df=cluster_df[cluster_df['Cluster']==2]
cluster_4_df=cluster_df[cluster_df['Cluster']==3]
cluster_1_df
# Out:
#           balance  balance_frequency  purchases  oneoff_purchases  \
# 1     3202.467416           0.909091       0.00              0.00
# 15    6886.213231           1.000000    1611.70              0.00
# 23    3800.151377           0.818182    4248.35           3454.56
# 24    5368.571219           1.000000       0.00              0.00
# 28    7152.864372           1.000000     387.05            204.55
# ...           ...                ...        ...               ...
# 8857  2330.222764           1.000000    1320.00              0.00
# 8858   812.934042           1.000000      50.00             50.00
# 8869  2171.222526           1.000000     791.18            791.18
# 8915   381.341657           1.000000      78.00              0.00
# 8941  5967.475270           0.833333     214.55              0.00
#
#       installments_purchases  cash_advance  purchases_frequency  \
# 1                       0.00   6442.945483             0.000000
# ...

# %%
cluster_2_df
# Out:
#           balance  balance_frequency  purchases  oneoff_purchases  \
# 2     2495.148862           1.000000     773.17            773.17
# 5     1809.828751           1.000000    1333.28              0.00
# 7     1823.652743           1.000000     436.20              0.00
# 10    1293.124939           1.000000     920.12              0.00
# 12    1516.928620           1.000000    3217.99           2500.23
# ...           ...                ...        ...               ...
# 8940   130.838554           1.000000     591.24              0.00
# 8942    40.829749           1.000000     113.28              0.00
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
#
#       installments_purchases  cash_advance  purchases_frequency  \
# 2                       0.00           0.0             1.000000
# ...

# %%
cluster_3_df
# Out:
#           balance  balance_frequency  purchases  oneoff_purchases  \
# 0       40.900749           0.818182      95.40              0.00
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# 8     1014.926473           1.000000     861.49            661.49
# 9      152.225975           0.545455    1281.60           1281.60
# ...           ...                ...        ...               ...
# 8939   728.352548           1.000000     734.40            734.40
# 8943     5.871712           0.500000      20.90             20.90
# 8944   193.571722           0.833333    1012.73           1012.73
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       installments_purchases  cash_advance  purchases_frequency  \
# 0                       95.4      0.000000             0.166667
# ...

# %%
cluster_4_df
# Out:
#           balance  balance_frequency  purchases  oneoff_purchases  \
# 6      627.260806           1.000000    7091.01           6402.63
# 21    6369.531318           1.000000    6359.95           5910.04
# 57    2386.330629           1.000000    5217.62           4789.09
# 84    1935.362486           1.000000    4915.60           4515.34
# 90    9381.255094           1.000000    5100.07           1147.83
# ...           ...                ...        ...               ...
# 8215  4436.557694           1.000000    6005.90           5838.38
# 8541  3326.323283           1.000000    8209.77           2218.28
# 8662   599.909949           1.000000    4947.32           3149.59
# 8689   368.318662           0.909091    8053.95           8053.95
# 8737  2533.618119           0.909091    5633.83           2985.92
#
#       installments_purchases  cash_advance  purchases_frequency  \
# 6                     688.38      0.000000             1.000000
# ...

# %% [markdown]
# # visualization

# %%
sns.countplot(x='Cluster',data=cluster_df)

# %%
for c in cluster_df.drop(['Cluster'],axis=1):
    grid=sns.FacetGrid(cluster_df,col='Cluster')
    grid=grid.map(plt.hist,c)
plt.show()

# %% [markdown]
# ## saving the kmeans clustering model and the data with cluster label

# %%
# saving scikitlearn model

# %%
import joblib

joblib.dump(kmeans_model,'kmeans_model.pkl')
# Out:
# ['kmeans_model.pkl']

# %%
cluster_df.to_csv('clustering_customer_data.csv')

# %% [markdown]
# # training and testing the model accuracy using decision tree

# %%
# split dataset

X=cluster_df.drop(['Cluster'],axis=1)
y=cluster_df[['Cluster']]

# %%
X
# Out:
#           balance  balance_frequency  purchases  oneoff_purchases  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       installments_purchases  cash_advance  purchases_frequency  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
y
# Out:
#       Cluster
# 0           2
# 1           0
# 2           1
# 3           2
# 4           2
# ...       ...
# 8945        1
# 8946        1
# 8947        1
# 8948        2
# 8949        2
#
# [8950 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %% [markdown]
# ### Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier(criterion='entropy')
model.fit(X_train,y_train)
y_pred=model.predict(X_test)

# %% [markdown]
# ### confusion matrix

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 309   16   31    1]
#  [   8  955   37   12]
#  [  12   36 1130    2]
#  [   3   17    2  114]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90       357
#            1       0.93      0.94      0.94      1012
#            2       0.94      0.96      0.95      1180
#            3       0.88      0.84      0.86       136
#
#     accuracy                           0.93      2685
#    macro avg       0.92      0.90      0.91      2685
# weighted avg       0.93      0.93      0.93      2685

# %% [markdown]
# ### saving the decision tree model for future prediction

# %%
import pickle

# %%
filename='final_model.sav'
pickle.dump(model,open(filename,'wb'))

# %%
# some time later

# %%
# load the model from  disk for prediction

# %%
loaded_model=pickle.load(open(filename,'rb'))
result=loaded_model.score(X_test,y_test)
print(result,'% Accuracy')
# Out:
# 0.9340782122905028 % Accuracy
